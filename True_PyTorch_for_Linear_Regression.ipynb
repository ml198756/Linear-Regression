# %%
import torch
x_data = torch.Tensor([[1.0], [2.0], [3.0]])
y_data = torch.Tensor([[2.0], [4.0], [6.0]])

class LinearModel(torch.nn.Module):
    def __init__(self):
        super(LinearModel, self).__init__()
        self.linear = torch.nn.Linear(1, 1)

    def forward(self, x):
        y_pred = self.linear(x)
        return y_pred
    
model = LinearModel()

criterion = torch.nn.MSELoss(reduction='sum')
optimizer = torch.optim.SGD(model.parameters(), lr=0.01)

for epoch in range(100):
    y_pred = model(x_data)
    loss = criterion(y_pred, y_data)
    print(epoch, loss)

    optimizer.zero_grad()
    loss.backward()
    optimizer.step()

print('w=', model.linear.weight.item())
print('b=', model.linear.bias.item())

x_test = torch.Tensor([4.0])
y_test = model(x_test)
print('y_pred=', y_test.data)
# Out:
# 0 tensor(155.1067, grad_fn=<MseLossBackward0>)
# 1 tensor(69.0620, grad_fn=<MseLossBackward0>)
# 2 tensor(30.7571, grad_fn=<MseLossBackward0>)
# 3 tensor(13.7047, grad_fn=<MseLossBackward0>)
# 4 tensor(6.1133, grad_fn=<MseLossBackward0>)
# 5 tensor(2.7336, grad_fn=<MseLossBackward0>)
# 6 tensor(1.2289, grad_fn=<MseLossBackward0>)
# 7 tensor(0.5589, grad_fn=<MseLossBackward0>)
# 8 tensor(0.2604, grad_fn=<MseLossBackward0>)
# 9 tensor(0.1274, grad_fn=<MseLossBackward0>)
# 10 tensor(0.0680, grad_fn=<MseLossBackward0>)
# 11 tensor(0.0414, grad_fn=<MseLossBackward0>)
# 12 tensor(0.0294, grad_fn=<MseLossBackward0>)
# 13 tensor(0.0239, grad_fn=<MseLossBackward0>)
# 14 tensor(0.0213, grad_fn=<MseLossBackward0>)
# 15 tensor(0.0200, grad_fn=<MseLossBackward0>)
# 16 tensor(0.0193, grad_fn=<MseLossBackward0>)
# 17 tensor(0.0188, grad_fn=<MseLossBackward0>)
# 18 tensor(0.0184, grad_fn=<MseLossBackward0>)
# 19 tensor(0.0181, grad_fn=<MseLossBackward0>)
# 20 tensor(0.0178, grad_fn=<MseLossBackward0>)
# 21 tensor(0.0176, grad_fn=<MseLossBackward0>)
# 22 tensor(0.0173, grad_fn=<MseLossBackward0>)
# 23 tensor(0.0171, grad_fn=<MseLossBackward0>)
# 24 tensor(0.0168, grad_fn=<MseLossBackward0>)
# 25 tensor(0.0166, grad_fn=<MseLossBackward0>)
# 26 tensor(0.0163, grad_fn=<MseLossBackward0>)
# 27 tensor(0.0161, grad_fn=<MseLossBackward0>)
# 28 tensor(0.0159, grad_fn=<MseLossBackward0>)
# 29 tensor(0.0156, grad_fn=<MseLossBackward0>)
# 30 tensor(0.0154, grad_fn=<MseLossBackward0>)
# 31 tensor(0.0152, grad_fn=<MseLossBackward0>)
# 32 tensor(0.0150, grad_fn=<MseLossBackward0>)
# 33 tensor(0.0148, grad_fn=<MseLossBackward0>)
# 34 tensor(0.0146, grad_fn=<MseLossBackward0>)
# 35 tensor(0.0143, grad_fn=<MseLossBackward0>)
# 36 tensor(0.0141, grad_fn=<MseLossBackward0>)
# 37 tensor(0.0139, grad_fn=<MseLossBackward0>)
# 38 tensor(0.0137, grad_fn=<MseLossBackward0>)
# 39 tensor(0.0135, grad_fn=<MseLossBackward0>)
# 40 tensor(0.0133, grad_fn=<MseLossBackward0>)
# 41 tensor(0.0132, grad_fn=<MseLossBackward0>)
# 42 tensor(0.0130, grad_fn=<MseLossBackward0>)
# 43 tensor(0.0128, grad_fn=<MseLossBackward0>)
# 44 tensor(0.0126, grad_fn=<MseLossBackward0>)
# 45 tensor(0.0124, grad_fn=<MseLossBackward0>)
# 46 tensor(0.0122, grad_fn=<MseLossBackward0>)
# 47 tensor(0.0121, grad_fn=<MseLossBackward0>)
# 48 tensor(0.0119, grad_fn=<MseLossBackward0>)
# 49 tensor(0.0117, grad_fn=<MseLossBackward0>)
# 50 tensor(0.0115, grad_fn=<MseLossBackward0>)
# 51 tensor(0.0114, grad_fn=<MseLossBackward0>)
# 52 tensor(0.0112, grad_fn=<MseLossBackward0>)
# 53 tensor(0.0111, grad_fn=<MseLossBackward0>)
# 54 tensor(0.0109, grad_fn=<MseLossBackward0>)
# 55 tensor(0.0107, grad_fn=<MseLossBackward0>)
# 56 tensor(0.0106, grad_fn=<MseLossBackward0>)
# 57 tensor(0.0104, grad_fn=<MseLossBackward0>)
# 58 tensor(0.0103, grad_fn=<MseLossBackward0>)
# 59 tensor(0.0101, grad_fn=<MseLossBackward0>)
# 60 tensor(0.0100, grad_fn=<MseLossBackward0>)
# 61 tensor(0.0098, grad_fn=<MseLossBackward0>)
# 62 tensor(0.0097, grad_fn=<MseLossBackward0>)
# 63 tensor(0.0096, grad_fn=<MseLossBackward0>)
# 64 tensor(0.0094, grad_fn=<MseLossBackward0>)
# 65 tensor(0.0093, grad_fn=<MseLossBackward0>)
# 66 tensor(0.0092, grad_fn=<MseLossBackward0>)
# 67 tensor(0.0090, grad_fn=<MseLossBackward0>)
# 68 tensor(0.0089, grad_fn=<MseLossBackward0>)
# 69 tensor(0.0088, grad_fn=<MseLossBackward0>)
# 70 tensor(0.0086, grad_fn=<MseLossBackward0>)
# 71 tensor(0.0085, grad_fn=<MseLossBackward0>)
# 72 tensor(0.0084, grad_fn=<MseLossBackward0>)
# 73 tensor(0.0083, grad_fn=<MseLossBackward0>)
# 74 tensor(0.0082, grad_fn=<MseLossBackward0>)
# 75 tensor(0.0080, grad_fn=<MseLossBackward0>)
# 76 tensor(0.0079, grad_fn=<MseLossBackward0>)
# 77 tensor(0.0078, grad_fn=<MseLossBackward0>)
# 78 tensor(0.0077, grad_fn=<MseLossBackward0>)
# 79 tensor(0.0076, grad_fn=<MseLossBackward0>)
# 80 tensor(0.0075, grad_fn=<MseLossBackward0>)
# 81 tensor(0.0074, grad_fn=<MseLossBackward0>)
# 82 tensor(0.0073, grad_fn=<MseLossBackward0>)
# 83 tensor(0.0072, grad_fn=<MseLossBackward0>)
# 84 tensor(0.0071, grad_fn=<MseLossBackward0>)
# 85 tensor(0.0070, grad_fn=<MseLossBackward0>)
# 86 tensor(0.0069, grad_fn=<MseLossBackward0>)
# 87 tensor(0.0068, grad_fn=<MseLossBackward0>)
# 88 tensor(0.0067, grad_fn=<MseLossBackward0>)
# 89 tensor(0.0066, grad_fn=<MseLossBackward0>)
# 90 tensor(0.0065, grad_fn=<MseLossBackward0>)
# 91 tensor(0.0064, grad_fn=<MseLossBackward0>)
# 92 tensor(0.0063, grad_fn=<MseLossBackward0>)
# 93 tensor(0.0062, grad_fn=<MseLossBackward0>)
# 94 tensor(0.0061, grad_fn=<MseLossBackward0>)
# 95 tensor(0.0060, grad_fn=<MseLossBackward0>)
# 96 tensor(0.0059, grad_fn=<MseLossBackward0>)
# 97 tensor(0.0058, grad_fn=<MseLossBackward0>)
# 98 tensor(0.0058, grad_fn=<MseLossBackward0>)
# 99 tensor(0.0057, grad_fn=<MseLossBackward0>)
# w= 1.949827790260315
# b= 0.11405304819345474
# y_pred= tensor([7.9134])
